# %% [markdown]
# <a href="https://colab.research.google.com/github/heispv/programming-feb2023/blob/master/18_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])


plt.subplot(2, 3, 1)
plt.title('1st')
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.title('2nd')
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.title('3rd')
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.title('4th')
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.title('5th')
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.title('6th')
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.title('House Price vs Meters')
plt.xlabel('Meters')
plt.ylabel('House Price')
plt.show()

# %% [markdown]
# > Mitoonim dota data mokhtalef ro ke mikhaim ba tavajoh be rangeshoon az ham dge motemayez bashan be soorate zir code mizanim.

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='k')

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color='b')

plt.title('Age vs Speed of different cars in two days')
plt.xlabel('Age')
plt.ylabel('Speed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import random

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85,99,86,87,88,111,86,103,87,94,78,77,85,86])
my_color = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100, 0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100, 100, 100])
plt.scatter(x, y, c=my_color, cmap='coolwarm')

plt.title('Temperature of different areas of the plate')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %% [markdown]
# > Mitoonim alave bar range data ha be oona size ham bedim

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import random

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85,99,86,87,88,111,86,103,87,94,78,77,85,86])
my_color = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100, 0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100, 100, 100])
my_size = np.array([0, 1, 2, 3, 4, 4.5, 5.0, 5.5, 6.0, 7.0, 8.0, 9.0, 10.0, 0, 1.0, 2.0, 3.0, 4.0, 4.5, 5.0, 5.5, 6.0, 7.0, 8.0, 9.0, 10.0, 10.0, 10.0])
plt.scatter(x, y, c=my_color, cmap='coolwarm', s=my_size)

plt.title('Temperature of different areas of the plate')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %% [markdown]
# > mitoonim az argument `alpha` baraye inke transparency o taghir bedim estefade konim.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 10))

plt.subplot(3, 2, 1)
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

plt.subplot(3, 2, 2)
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

plt.subplot(3, 2, 3)
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

plt.subplot(3, 2, 4)
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

plt.subplot(3, 2, 5)
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

plt.subplot(3, 2, 6)
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()


plt.show()

# %% [markdown]
# > Agar khastim adade random generate konim, ama alave bar inke random bashe khastim hardafe hamoon adad random generate beshe bayad seed e oonaro be komake `np.random.seed(adademoon)` moshakhas konim, agar adad sabet bashe va masale ham hich taghiri nakone hardafe khurujimoon yek chize sabet hast. ama agar masale taghir kone va ya adade seed emoon taghir kone dobare adade kamelan motefavet khahim dasht.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# > mitoonim start angle ro taghir bedim

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle=180)
plt.show()
