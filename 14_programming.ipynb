# %% [markdown]
# <a href="https://colab.research.google.com/github/heispv/programming-feb2023/blob/master/14_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [1, 2, 3]

# %%
len()
# Out:
# 3

# %%
name = 'there is nothing here'

# %%
name
# Out:
# 'there is nothing here'

# %%
def save_your_information():
  name = input('Enter your first name: ')
  last_name = input('Enter your last name: ')

  enter_age = input('Do you want to enter your age or not?[y/n] ')

  if enter_age == 'y':
    # Define the variable age
    age = input('Enter your age: ')
    information = {
        'Name': name,
        'Last Name': last_name,
        'Age': age
    }

  elif enter_age == 'n':
        information = {
        'Name': name,
        'Last Name': last_name
    }
  
  return information

# %%
save_your_information()
# Out:
# Enter your first name: Jack
# Enter your last name: Johnson
# Do you want to enter your age or not?[y/n] y
# Enter your age: 18
# {'Name': 'Jack', 'Last Name': 'Johnson', 'Age': '18'}

# %% [markdown]
# Mibinim ke variable `name` ke ghabl az funciton tarif kardim taghiri nakarde, va ba inke dakhele function emoon variable i be name `name` dashtim ama meghdare name taghir nakarde. chonke name e dakhele function kamelan ba name i ke biroon function tarif shode fargh mikonan va be ham rabti nadaran.

# %%
name
# Out:
# 'there is nothing here'

# %%
first_person = save_your_information()
# Out:
# Enter your first name: Lara
# Enter your last name: Croft
# Do you want to enter your age or not?[y/n] n

# %%
first_person
# Out:
# {'Name': 'Lara', 'Last Name': 'Croft'}

# %%
second_person = save_your_information()
# Out:
# Enter your first name: Mr
# Enter your last name: Bean
# Do you want to enter your age or not?[y/n] y
# Enter your age: 52

# %%
second_person
# Out:
# {'Name': 'Mr', 'Last Name': 'Bean', 'Age': '52'}

# %%
my_list = ['a', 'b', 'c']
my_list[0]
# Out:
# 'a'

# %%
second_person['Name']
# Out:
# 'Mr'

# %%
first_person['Name'], second_person['Name']
# Out:
# ('Lara', 'Mr')

# %%
def save_your_information_2():
  name = input('Enter your first name: ')
  last_name = input('Enter your last name: ')

  enter_age = input('Do you want to enter your age or not?[y/n] ')

  while True:
    if (enter_age == 'y') or (enter_age == 'n'):
      # yani inke user ma vurudi dorost dade, pas in halghe bayad shekaste beshe
      break
    else:
      enter_age = input('Pay attention to the correct format...\nOnly enter y or n: ')

  if enter_age == 'y':
    # Define the variable age
    age = input('Enter your age: ')
    information = {
        'Name': name,
        'Last Name': last_name,
        'Age': age
    }

  elif enter_age == 'n':
        information = {
        'Name': name,
        'Last Name': last_name
    }
  
  return information

# %%
save_your_information_2()
# Out:
# Enter your first name: Mohammad
# Enter your last name: Mohammadi
# Do you want to enter your age or not?[y/n] yes
# Pay attention to the correct format...
# Only enter y or n: NO
# Pay attention to the correct format...
# Only enter y or n: y
# Enter your age: 21
# {'Name': 'Mohammad', 'Last Name': 'Mohammadi', 'Age': '21'}

# %%
import random

random.choice([1, 2, 3, 4, 5])
# Out:
# 1

# %%
random.choice([1, 2, 3, 4, 5])
# Out:
# 1

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# %%
my_np = np.array([1, 2, 3, 4])

# %%
my_np
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# ![Screenshot (1).png](data:image/png;base64,...)
