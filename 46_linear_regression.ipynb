# %% [markdown]
# <a href="https://colab.research.google.com/github/heispv/programming-feb2023/blob/master/46_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Biam va yek seri X tarif konim
X = np.linspace(-30, 50, 60) #Start, Stop, # of numbers
X
# Out:
# array([-30.        , -28.6440678 , -27.28813559, -25.93220339,
#        -24.57627119, -23.22033898, -21.86440678, -20.50847458,
#        -19.15254237, -17.79661017, -16.44067797, -15.08474576,
#        -13.72881356, -12.37288136, -11.01694915,  -9.66101695,
#         -8.30508475,  -6.94915254,  -5.59322034,  -4.23728814,
#         -2.88135593,  -1.52542373,  -0.16949153,   1.18644068,
#          2.54237288,   3.89830508,   5.25423729,   6.61016949,
#          7.96610169,   9.3220339 ,  10.6779661 ,  12.03389831,
#         13.38983051,  14.74576271,  16.10169492,  17.45762712,
#         18.81355932,  20.16949153,  21.52542373,  22.88135593,
#         24.23728814,  25.59322034,  26.94915254,  28.30508475,
#         29.66101695,  31.01694915,  32.37288136,  33.72881356,
#         35.08474576,  36.44067797,  37.79661017,  39.15254237,
#         40.50847458,  41.86440678,  43.22033898,  44.57627119,
#         45.93220339,  47.28813559,  48.6440678 ,  50.        ])

# %%
# Baraye tarif kardane y
shib = 2
arz_az_mabda = 1.5

y = (X * shib) + arz_az_mabda

# %%
y
# Out:
# array([-58.5       , -55.78813559, -53.07627119, -50.36440678,
#        -47.65254237, -44.94067797, -42.22881356, -39.51694915,
#        -36.80508475, -34.09322034, -31.38135593, -28.66949153,
#        -25.95762712, -23.24576271, -20.53389831, -17.8220339 ,
#        -15.11016949, -12.39830508,  -9.68644068,  -6.97457627,
#         -4.26271186,  -1.55084746,   1.16101695,   3.87288136,
#          6.58474576,   9.29661017,  12.00847458,  14.72033898,
#         17.43220339,  20.1440678 ,  22.8559322 ,  25.56779661,
#         28.27966102,  30.99152542,  33.70338983,  36.41525424,
#         39.12711864,  41.83898305,  44.55084746,  47.26271186,
#         49.97457627,  52.68644068,  55.39830508,  58.11016949,
#         60.8220339 ,  63.53389831,  66.24576271,  68.95762712,
#         71.66949153,  74.38135593,  77.09322034,  79.80508475,
#         82.51694915,  85.22881356,  87.94067797,  90.65254237,
#         93.36440678,  96.07627119,  98.78813559, 101.5       ])

# %%
# biaim va nemoodar ro bebinim che shekli mishe
plt.scatter(X, y)
plt.show()

# %%
# Biam va noise ezafe konim be datamoon
shib = 2
arz_az_mabda = 1.5
noise = 0.2

y = (X * shib) + arz_az_mabda + (np.random.randn(len(X)) * noise * np.abs(X))

# %%
plt.scatter(X, y)
plt.show()

# %%
# Biam va noise ezafe konim be datamoon ama bar asase index e X
shib = 2
arz_az_mabda = 1.5
noise = 0.2
index = np.arange(len(X))

y = (X * shib) + arz_az_mabda + (np.random.randn(len(X)) * noise * index)

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# # Sakhtane Model be komake TF
#
# 1. Model ro be komake `Sequential API` e TF misazim.
# 2. Model ro `compile` mikonim.
# * yani `optimizer` va `loss function` va `metrics` ro barash tain mikonam.
# 3. Model ro `train` mikonim.

# %%
X.shape
# Out:
# (60,)

# %% [markdown]
# ![tf1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## First model

# %%
# 1. Sakhtane model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# %%
# 2. Compile the model
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001),
    loss=tf.keras.losses.mse,
    metrics=['accuracy']
)

# %%
# 3. Fit the model
history = model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 7s 48ms/step - loss: 194.4775 - accuracy: 0.0000e+00
# Epoch 2/20
# 2/2 [==============================] - 0s 44ms/step - loss: 142.3473 - accuracy: 0.0000e+00
# Epoch 3/20
# 2/2 [==============================] - 0s 34ms/step - loss: 112.0842 - accuracy: 0.0000e+00
# Epoch 4/20
# 2/2 [==============================] - 0s 29ms/step - loss: 95.2139 - accuracy: 0.0000e+00
# Epoch 5/20
# 2/2 [==============================] - 0s 60ms/step - loss: 83.3036 - accuracy: 0.0000e+00
# Epoch 6/20
# 2/2 [==============================] - 0s 45ms/step - loss: 77.3395 - accuracy: 0.0000e+00
# Epoch 7/20
# 2/2 [==============================] - 0s 38ms/step - loss: 76.0988 - accuracy: 0.0000e+00
# Epoch 8/20
# 2/2 [==============================] - 0s 43ms/step - loss: 73.4856 - accuracy: 0.0000e+00
# Epoch 9/20
# 2/2 [==============================] - 0s 25ms/step - loss: 72.5881 - accuracy: 0.0000e+00
# Epoch 10/20
# 2/2 [==============================] - 0s 20ms/step - loss: 71.7124 - accuracy: 0.0000e+00
# Epoch 11/20
# 2/2 [==============================] - 0s 31ms/step - loss: 72.0407 - accuracy: 0.0000e+00
# Epoch 12/20
# 2/2 [==============================] - 0s 30ms/step - loss: 71.2840 - accuracy: 0.0000e+00
# Epoch 13/20
# 2/2 [==============================] - 0s 28ms/step - loss: 71.0978 - accuracy: 0.0000e+00
# Epoch 14/20
# 2/2 [==============================] - 0s 35ms/step - loss: 70.7748 - accuracy: 0.0000e+00
# Epoch 15/20
# 2/2 [==============================] - 0s 59ms/step - loss: 71.0317 - accuracy: 0.0000e+00
# Epoch 16/20
# 2/2 [==============================] - 0s 31ms/step - loss: 72.0934 - accuracy: 0.0000e+00
# Epoch 17/20
# 2/2 [==============================] - 0s 31ms/step - loss: 71.7048 - accuracy: 0.0000e+00
# Epoch 18/20
# 2/2 [==============================] - 0s 42ms/step - loss: 71.7354 - accuracy: 0.0000e+00
# Epoch 19/20
# 2/2 [==============================] - 0s 34ms/step - loss: 71.4463 - accuracy: 0.0000e+00
# Epoch 20/20
# 2/2 [==============================] - 0s 44ms/step - loss: 71.8520 - accuracy: 0.0000e+00

# %%
plt.plot(history.history["loss"])
plt.title("Model's Performance")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %% [markdown]
# ## Second model
# Inja mikhaim ghabl az sakhte model data moon ro normalize konim

# %%
X
# Out:
# array([-30.        , -28.6440678 , -27.28813559, -25.93220339,
#        -24.57627119, -23.22033898, -21.86440678, -20.50847458,
#        -19.15254237, -17.79661017, -16.44067797, -15.08474576,
#        -13.72881356, -12.37288136, -11.01694915,  -9.66101695,
#         -8.30508475,  -6.94915254,  -5.59322034,  -4.23728814,
#         -2.88135593,  -1.52542373,  -0.16949153,   1.18644068,
#          2.54237288,   3.89830508,   5.25423729,   6.61016949,
#          7.96610169,   9.3220339 ,  10.6779661 ,  12.03389831,
#         13.38983051,  14.74576271,  16.10169492,  17.45762712,
#         18.81355932,  20.16949153,  21.52542373,  22.88135593,
#         24.23728814,  25.59322034,  26.94915254,  28.30508475,
#         29.66101695,  31.01694915,  32.37288136,  33.72881356,
#         35.08474576,  36.44067797,  37.79661017,  39.15254237,
#         40.50847458,  41.86440678,  43.22033898,  44.57627119,
#         45.93220339,  47.28813559,  48.6440678 ,  50.        ])

# %% [markdown]
# Be komake `X.mean()` miangin data haro migirim va be komake `X.std()` standard deviation oon ro hesab mikonim chonke baraye normalize kardane data bayad har data ro menhaye miangin konim va bar standard deviation oon taghsim konim

# %%
X_normalized = (X - X.mean()) / X.std()
y_normalized = (y - y.mean()) / y.std()

# %% [markdown]
# * agar check konim mibinim ke X_normalized miangin esh 0 hast va standard deviation oon barabar ba 1 hastesh ke in model parakandegi data baraye Neural Network kheyli khoobe va yadgiri ro behtar mikone.

# %%
X_normalized
# Out:
# array([-1.7034199 , -1.64567685, -1.5879338 , -1.53019075, -1.47244771,
#        -1.41470466, -1.35696161, -1.29921857, -1.24147552, -1.18373247,
#        -1.12598942, -1.06824638, -1.01050333, -0.95276028, -0.89501723,
#        -0.83727419, -0.77953114, -0.72178809, -0.66404504, -0.606302  ,
#        -0.54855895, -0.4908159 , -0.43307286, -0.37532981, -0.31758676,
#        -0.25984371, -0.20210067, -0.14435762, -0.08661457, -0.02887152,
#         0.02887152,  0.08661457,  0.14435762,  0.20210067,  0.25984371,
#         0.31758676,  0.37532981,  0.43307286,  0.4908159 ,  0.54855895,
#         0.606302  ,  0.66404504,  0.72178809,  0.77953114,  0.83727419,
#         0.89501723,  0.95276028,  1.01050333,  1.06824638,  1.12598942,
#         1.18373247,  1.24147552,  1.29921857,  1.35696161,  1.41470466,
#         1.47244771,  1.53019075,  1.5879338 ,  1.64567685,  1.7034199 ])

# %%
X_normalized.std()
# Out:
# 0.9999999999999999

# %% [markdown]
# ![tf1.JPG](data:image/jpeg;base64,...![tf2.JPG](data:image/jpeg;base64,...))

# %%
# 1. Sakhtane model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# %%
# 2. Compile the model
model_2.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.mse,
    metrics=['accuracy']
)

# %%
# 3. Fit the model
history = model_2.fit(X_normalized, y_normalized, epochs=50)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 11ms/step - loss: 6.6960 - accuracy: 0.0000e+00
# Epoch 2/50
# 2/2 [==============================] - 0s 24ms/step - loss: 6.1866 - accuracy: 0.0000e+00
# Epoch 3/50
# 2/2 [==============================] - 0s 24ms/step - loss: 5.7094 - accuracy: 0.0000e+00
# Epoch 4/50
# 2/2 [==============================] - 0s 37ms/step - loss: 5.2678 - accuracy: 0.0000e+00
# Epoch 5/50
# 2/2 [==============================] - 0s 17ms/step - loss: 4.8607 - accuracy: 0.0000e+00
# Epoch 6/50
# 2/2 [==============================] - 0s 13ms/step - loss: 4.4857 - accuracy: 0.0000e+00
# Epoch 7/50
# 2/2 [==============================] - 0s 10ms/step - loss: 4.1389 - accuracy: 0.0000e+00
# Epoch 8/50
# 2/2 [==============================] - 0s 10ms/step - loss: 3.8202 - accuracy: 0.0000e+00
# Epoch 9/50
# 2/2 [==============================] - 0s 11ms/step - loss: 3.5272 - accuracy: 0.0000e+00
# Epoch 10/50
# 2/2 [==============================] - 0s 10ms/step - loss: 3.2559 - accuracy: 0.0000e+00
# Epoch 11/50
# 2/2 [==============================] - 0s 10ms/step - loss: 3.0062 - accuracy: 0.0000e+00
# Epoch 12/50
# 2/2 [==============================] - 0s 19ms/step - loss: 2.7752 - accuracy: 0.0000e+00
# Epoch 13/50
# 2/2 [==============================] - 0s 13ms/step - loss: 2.5637 - accuracy: 0.0000e+00
# Epoch 14/50
# 2/2 [==============================] - 0s 14ms/step - loss: 2.3626 - accuracy: 0.0000e+00
# Epoch 15/50
# 2/2 [==============================] - 0s 11ms/step - loss: 2.1820 - accuracy: 0.0000e+00
# Epoch 16/50
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0153 - accuracy: 0.0000e+00
# Epoch 17/50
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8624 - accuracy: 0.0000e+00
# Epoch 18/50
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7199 - accuracy: 0.0000e+00
# Epoch 19/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.5884 - accuracy: 0.0000e+00
# Epoch 20/50
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4693 - accuracy: 0.0000e+00
# Epoch 21/50
# 2/2 [==============================] - 0s 49ms/step - loss: 1.3574 - accuracy: 0.0000e+00
# Epoch 22/50
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2533 - accuracy: 0.0000e+00
# Epoch 23/50
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1578 - accuracy: 0.0000e+00
# Epoch 24/50
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0698 - accuracy: 0.0000e+00
# Epoch 25/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9894 - accuracy: 0.0000e+00
# Epoch 26/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9166 - accuracy: 0.0000e+00
# Epoch 27/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8467 - accuracy: 0.0000e+00
# Epoch 28/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.7835 - accuracy: 0.0000e+00
# Epoch 29/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7265 - accuracy: 0.0000e+00
# Epoch 30/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6721 - accuracy: 0.0000e+00
# Epoch 31/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6235 - accuracy: 0.0000e+00
# Epoch 32/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5771 - accuracy: 0.0000e+00
# Epoch 33/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5343 - accuracy: 0.0000e+00
# Epoch 34/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4957 - accuracy: 0.0000e+00
# Epoch 35/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4598 - accuracy: 0.0000e+00
# Epoch 36/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4270 - accuracy: 0.0000e+00
# Epoch 37/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3962 - accuracy: 0.0000e+00
# Epoch 38/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3684 - accuracy: 0.0000e+00
# Epoch 39/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3423 - accuracy: 0.0000e+00
# Epoch 40/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3184 - accuracy: 0.0000e+00
# Epoch 41/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2957 - accuracy: 0.0000e+00
# Epoch 42/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2755 - accuracy: 0.0000e+00
# Epoch 43/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2566 - accuracy: 0.0000e+00
# Epoch 44/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2392 - accuracy: 0.0000e+00
# Epoch 45/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2235 - accuracy: 0.0000e+00
# Epoch 46/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2083 - accuracy: 0.0000e+00
# Epoch 47/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1946 - accuracy: 0.0000e+00
# Epoch 48/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1822 - accuracy: 0.0000e+00
# Epoch 49/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1704 - accuracy: 0.0000e+00
# Epoch 50/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1600 - accuracy: 0.0000e+00

# %%
plt.plot(history.history["loss"])
plt.title("Model's Performance")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %% [markdown]
# ## How to split the data to training set and validation set
#
# Az validation dataset baraye in estefade mikonim ke bebenim model emoon rooye data i ke nadide chejuri amal mikone, chonke nabayd perofrmance model ro rooye training dataset check konim, balke bayad bebinim aya model emoon generalize (overfit nashe) mishe nesbat be dade haye dge.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized,
                                                    y_normalized,
                                                    test_size=0.2)

# %%
X_train.shape
# Out:
# (48,)

# %%
y_train.shape
# Out:
# (48,)

# %%
X_train.shape, X_test.shape
# Out:
# ((48,), (12,))

# %%
# 1. Sakhtane model
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# %%
# 2. Compile the model
model_3.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.mse
)

# %%
# 3. Fit the model
history_3 = model_3.fit(X_train,
                        y_train,
                        epochs=50,
                        validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 642ms/step - loss: 0.5632 - val_loss: 0.4218
# Epoch 2/50
# 2/2 [==============================] - 0s 139ms/step - loss: 0.5228 - val_loss: 0.3885
# Epoch 3/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.4836 - val_loss: 0.3597
# Epoch 4/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4481 - val_loss: 0.3317
# Epoch 5/50
# 2/2 [==============================] - 0s 177ms/step - loss: 0.4144 - val_loss: 0.3066
# Epoch 6/50
# 2/2 [==============================] - 0s 137ms/step - loss: 0.3840 - val_loss: 0.2836
# Epoch 7/50
# 2/2 [==============================] - 0s 162ms/step - loss: 0.3570 - val_loss: 0.2635
# Epoch 8/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.3327 - val_loss: 0.2450
# Epoch 9/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.3091 - val_loss: 0.2260
# Epoch 10/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2866 - val_loss: 0.2087
# Epoch 11/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2656 - val_loss: 0.1927
# Epoch 12/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.2464 - val_loss: 0.1776
# Epoch 13/50
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2285 - val_loss: 0.1651
# Epoch 14/50
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2132 - val_loss: 0.1534
# Epoch 15/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1985 - val_loss: 0.1416
# Epoch 16/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1843 - val_loss: 0.1314
# Epoch 17/50
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1723 - val_loss: 0.1228
# Epoch 18/50
# 2/2 [==============================] - 0s 138ms/step - loss: 0.1616 - val_loss: 0.1143
# Epoch 19/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.1516 - val_loss: 0.1072
# Epoch 20/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1424 - val_loss: 0.1002
# Epoch 21/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1338 - val_loss: 0.0939
# Epoch 22/50
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1258 - val_loss: 0.0882
# Epoch 23/50
# 2/2 [==============================] - 0s 126ms/step - loss: 0.1188 - val_loss: 0.0831
# Epoch 24/50
# 2/2 [==============================] - 0s 129ms/step - loss: 0.1124 - val_loss: 0.0786
# Epoch 25/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.1064 - val_loss: 0.0739
# Epoch 26/50
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1006 - val_loss: 0.0697
# Epoch 27/50
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0954 - val_loss: 0.0661
# Epoch 28/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0907 - val_loss: 0.0626
# Epoch 29/50
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0863 - val_loss: 0.0594
# Epoch 30/50
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0821 - val_loss: 0.0562
# Epoch 31/50
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0781 - val_loss: 0.0535
# Epoch 32/50
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0745 - val_loss: 0.0506
# Epoch 33/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0709 - val_loss: 0.0482
# Epoch 34/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0680 - val_loss: 0.0463
# Epoch 35/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0655 - val_loss: 0.0445
# Epoch 36/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0631 - val_loss: 0.0426
# Epoch 37/50
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0607 - val_loss: 0.0408
# Epoch 38/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0584 - val_loss: 0.0394
# Epoch 39/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0568 - val_loss: 0.0384
# Epoch 40/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0552 - val_loss: 0.0367
# Epoch 41/50
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0529 - val_loss: 0.0355
# Epoch 42/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0515 - val_loss: 0.0346
# Epoch 43/50
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0501 - val_loss: 0.0335
# Epoch 44/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0487 - val_loss: 0.0326
# Epoch 45/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0475 - val_loss: 0.0318
# Epoch 46/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0465 - val_loss: 0.0312
# Epoch 47/50
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0456 - val_loss: 0.0304
# Epoch 48/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0445 - val_loss: 0.0298
# Epoch 49/50
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0437 - val_loss: 0.0293
# Epoch 50/50
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0429 - val_loss: 0.0287

# %%
# X_test ro bebinim
X_test
# Out:
# array([-0.43307286,  1.06824638, -0.25984371,  0.4908159 ,  1.5879338 ,
#        -1.24147552,  1.12598942,  0.31758676,  0.95276028, -1.47244771,
#        -0.606302  , -0.08661457])

# %%
# Make predictions on the test set
y_pred = model_3.predict(X_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 131ms/step
# array([[-0.4531627 ],
#        [ 1.1530439 ],
#        [-0.26783115],
#        [ 0.5352722 ],
#        [ 1.7090385 ],
#        [-1.318043  ],
#        [ 1.2148211 ],
#        [ 0.3499406 ],
#        [ 1.0294895 ],
#        [-1.5651518 ],
#        [-0.6384942 ],
#        [-0.08249962]], dtype=float32)

# %%
# Plot the results
plt.scatter(X_train, y_train, color='green', label='Training Data')
plt.scatter(X_test, y_test, color='blue', label='Actual Test Data')
plt.scatter(X_test, y_pred, color='red', label='Predicted Test Data')
plt.title('Training, Prediction vs Actual')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import imageio
from sklearn.model_selection import train_test_split

# Generate and normalize data
X = np.linspace(-30, 60, 60)
slope = 3
intercept = 2
noise_intensity = 0.3
y = slope * X + intercept + np.random.randn(len(X)) * noise_intensity * np.arange(len(X))
X_normalized = (X - X.mean()) / X.std()
y_normalized = (y - y.mean()) / y.std()

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y_normalized, test_size=0.2)

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
              loss='mean_squared_error')

# Custom callback to save weights
class SaveWeightsCallback(tf.keras.callbacks.Callback):
    def __init__(self, weights_list):
        super(SaveWeightsCallback, self).__init__()
        self.weights_list = weights_list

    def on_epoch_end(self, epoch, logs=None):
        weights, bias = self.model.layers[0].get_weights()
        self.weights_list.append((weights.flatten()[0], bias.flatten()[0]))

weights_list = []
save_weights_callback = SaveWeightsCallback(weights_list)

# Train the model
model.fit(X_train, y_train, epochs=100, verbose=0, callbacks=[save_weights_callback])

# Generate plots for each epoch and save them
for epoch, (weight, bias) in enumerate(weights_list):
    y_pred = weight * X_normalized + bias
    plt.figure(figsize=(10, 6))
    plt.scatter(X_normalized, y_normalized, color='blue', label='Data')
    plt.plot(X_normalized, y_pred, color='red', label=f'Epoch {epoch}')
    plt.title(f'Prediction Line at Epoch {epoch}')
    plt.xlabel('X')
    plt.ylabel('y')
    plt.legend()
    plt.savefig(f'plot_epoch_{epoch}.png')
    plt.close()

# Compile the images into a GIF
images = []
for epoch in range(len(weights_list)):
    images.append(imageio.imread(f'plot_epoch_{epoch}.png'))
imageio.mimsave('model_training.gif', images, fps=15)
# Out:
# <ipython-input-34-d9e7afa56ff3>:60: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(f'plot_epoch_{epoch}.png'))

# %% [markdown]
# # Exercise
# 1. Yek data amade konin ke yek moadele daraje 2 hast. noise ro ham behesh ezafe konin.
# 2. yek neural network besazin ke input_shape=(1,) hast, bad Dense layer ba 4 neuron dare, bad yek Dense layer ba 1 neuron dare.
# 3. Data ro be 15% baraye validation va 85% baraye train taghsim konin.
# 4. Va model ro train konin va nemoodaresh ro rasm konin, training set, validation set va prediction ro ba rang haye mokhtalef va nemoodare scatter plot neshoon bedin.
#
# * normalize kardane data faramoosh nashe.

# %% [markdown]
# ## more complex regression problem

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset
url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv"
insurance = pd.read_csv(url)

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Manual preprocessing
# One-hot encode categorical variables
insurance_onehot = pd.get_dummies(insurance, columns=['sex', 'smoker', 'region'], drop_first=True)

# %%
insurance_onehot.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400     False        True             False
# 1   18  33.770         1   1725.55230      True       False             False
# 2   28  33.000         3   4449.46200      True       False             False
# 3   33  22.705         0  21984.47061      True       False              True
# 4   32  28.880         0   3866.85520      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False
