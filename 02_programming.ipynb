# %% [markdown]
# # What is Github?
#
# GitHub is a popular platform for version control and collaboration on software development projects.
#
# There are three main ways to use GitHub:
# 1. GitHub website: The GitHub website provides a user-friendly interface for creating and managing repositories, as well as committing changes and collaborating with others.
# 2. GitHub Desktop: GitHub Desktop is a downloadable application that provides a graphical interface for managing repositories and making commits. It simplifies the process of working with Git, the underlying version control system that powers GitHub.
# 3. Git Bash: Git Bash is a command-line interface that allows you to work with Git and GitHub using text-based commands. It provides more control and flexibility than the graphical interfaces, but may be less user-friendly for beginners.
#
# By using any of these three methods, you can create and manage repositories, commit changes to them, and collaborate with others on software development projects.

# %% [markdown]
# ![Screenshot (97).png](data:image/png;base64,...)

# %% [markdown]
# # Git Bash
#
# `ls`: Lists the files and directories in the current directory.
#
# `cd`: Changes the current directory to the specified directory.
#
# `touch`: Creates a new file with the specified name.
#
# `mkdir`: Creates a new directory with the specified name.
#
# `rm`: Deletes the specified file or directory.
#
# `git init`: Initializes a new Git repository in the current directory.
#
# `git clone [repository URL]`: Clones an existing repository from a remote location to your local machine.
#
# `git add [file(s)]`: Adds the specified file(s) to the staging area, preparing them to be committed.
#
# `git commit -m "[commit message]"`: Commits the changes in the staging area to the repository with a descriptive commit message.
#
# `git status`: Displays the current status of the repository, including which files are staged and which have been modified.
#
# `git branch`: Lists all branches in the repository.
#
# `git checkout [branch name]`: Switches to the specified branch.
#
# `git merge [branch name]`: Merges the specified branch into the current branch.
#
# `git pull`: Fetches changes from the remote repository and merges them into the current branch.
#
# `git push`: Pushes the changes in the current branch to the remote repository.

# %% [markdown]
# # Data Types (continue)

# %%
# what is the type
type(5)
# Out:
# int

# %%
type(0.00001)
# Out:
# float

# %%
type(2 + 1.1)
# Out:
# float

# %%
type(2)
# Out:
# int

# %%
type(2.0)
# Out:
# float

# %%
# absolute of a number
abs(-230)
# Out:
# 230

# %%
# instead of using **
pow(3, 2)
# Out:
# 9

# %%
# we can round a number
round(3.2)
# Out:
# 3

# %%
round(3.7)
# Out:
# 4

# %% [markdown]
# # Operator precedence

# %% [markdown]
# Operator precedence in Python determines the order in which the operators in an expression are evaluated. When an expression contains multiple operators, Python follows a set of rules to determine which operator should be evaluated first. This is important, as it can affect the final result of the expression.
#
# Here is the complete list of operator precedence in Python, from highest to lowest:
#
# 1. Parentheses `()`
# 2. Exponentiation `**`
# 3. Multiplication `*`, Division `/`, and Floor division `//` (evaluated left to right)
# 4. Addition `+` and Subtraction `-` (evaluated left to right)
#
# It's worth noting that you can use parentheses to explicitly specify the order of operations in an expression, even if it doesn't follow the standard precedence rules. This can be especially helpful when working with complex expressions, or when you want to ensure that a specific operation is evaluated before others.
#
# By understanding and using operator precedence correctly in Python, you can write code that is easy to read and understand, and avoid potential bugs that can be difficult to debug.

# %%
20 + 3 * 2
# Out:
# 26

# %%
10 ** 2 * (3 + 4) / 2
# Out:
# 350.0

# %% [markdown]
# # Variable
#
# In Python, variables are used to store values that can be used later in the program. They allow you to assign a name to a value, making it easier to refer to that value throughout your code. Here are some important things to keep in mind when working with variables in Python:
#
# * Variable names should be written using underscores instead of spaces. This makes it easier to read and understand the name, and ensures that the name is a single entity. For example, you could use `first_name` instead of `first name`.
# * Variable names should not start with a number. This is because variable names must begin with a letter or an underscore, and can only contain letters, underscores, and numbers. For example, you could use `age` but not `2age`.
# * Python keywords cannot be used as variable names. Keywords are reserved words in Python that have special meanings and are used to define the language itself. For example, you cannot use `print`, `type`, `if` or other Python keywords as variable names.
# * If you want to indicate that a variable should not be changed, you can use all capital letters for its name. This is a convention in Python to indicate that a variable is a constant, meaning its value should not be modified throughout the program. For example, you could use `MAX_SIZE` instead of `max_size`.

# %%
age = 5

# %%
age_2 = 10

# %%
print(age)
# Out:
# 5

# %%
# to show that we are using constant
USERNAME = 'asdgac'

# %%
name, age, email = 'ali', 5, 'ali@yahoo.com'

# %%
print(name)
print(age)
print(email)
# Out:
# ali
# 5
# ali@yahoo.com
